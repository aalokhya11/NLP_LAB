# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.17.0

# %%
# Simple English to French dataset
data = [("hello", "bonjour"),
        ("how are you", "comment ça va"),
        ("I am fine", "je vais bien"),
        ("what is your name", "comment tu t'appelles"),
        ("my name is", "je m'appelle"),
        ("thank you", "merci"),
        ("goodbye", "au revoir")]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np


english_sentences = [pair[0] for pair in data]
french_sentences = [pair[1] for pair in data]


eng_tokenizer = Tokenizer()
fre_tokenizer = Tokenizer()

# Fit tokenizers on the respective sentences
eng_tokenizer.fit_on_texts(english_sentences)
fre_tokenizer.fit_on_texts(french_sentences)

# Convert the texts to sequences of integers
eng_sequences = eng_tokenizer.texts_to_sequences(english_sentences)
fre_sequences = fre_tokenizer.texts_to_sequences(french_sentences)

# Pad sequences to ensure uniform length
max_eng_len = max([len(seq) for seq in eng_sequences])
max_fre_len = max([len(seq) for seq in fre_sequences])

eng_padded = pad_sequences(eng_sequences, maxlen=max_eng_len, padding='post')
fre_padded = pad_sequences(fre_sequences, maxlen=max_fre_len, padding='post')

# Create the input and target data for training
input_data = np.array(eng_padded)
output_data = np.array(fre_padded)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense

# Define model parameters
embedding_dim = 64
latent_dim = 128

# Encoder
encoder_inputs = Input(shape=(max_eng_len,))
encoder_embedding = Embedding(input_dim=len(eng_tokenizer.word_index) + 1, output_dim=embedding_dim)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_embedding)

# Decoder
decoder_inputs = Input(shape=(max_fre_len,))
decoder_embedding = Embedding(input_dim=len(fre_tokenizer.word_index) + 1, output_dim=embedding_dim)(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=[state_h, state_c])
decoder_dense = Dense(len(fre_tokenizer.word_index) + 1, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Seq2Seq Model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Prepare target data for training by shifting the French sentence by one position
fre_target_data = np.zeros_like(output_data)
fre_target_data[:, :-1] = output_data[:, 1:]
fre_target_data[:, -1] = 0

# Train the Seq2Seq model
model.fit([input_data, output_data], fre_target_data, batch_size=16, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.0667 - loss: 2.6377 - val_accuracy: 0.8333 - val_loss: 2.6156
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6000 - loss: 2.6225 - val_accuracy: 0.8333 - val_loss: 2.5946
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5333 - loss: 2.6069 - val_accuracy: 0.8333 - val_loss: 2.5719
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5333 - loss: 2.5902 - val_accuracy: 0.8333 - val_loss: 2.5467
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5333 - loss: 2.5718 - val_accuracy: 0.8333 - val_loss: 2.5179
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5333 - loss: 2.5511 - val_accuracy: 0.8333 - val_loss: 2.4845
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5333 - loss: 2.5274 - val_accuracy: 0.8333 - val_loss: 2.4453
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5333 - loss: 2.4998 - val_accuracy: 0.8333 - val_loss: 2.3990
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.5333 - loss: 2.4674 - val_accuracy: 0.8333 - val_loss: 2.3439
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5333 - loss: 2.4292 - val_accuracy: 0.8333 - val_loss: 2.2782
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5333 - loss: 2.3837 - val_accuracy: 0.8333 - val_loss: 2.1994
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5333 - loss: 2.3294 - val_accuracy: 0.8333 - val_loss: 2.1051
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5333 - loss: 2.2645 - val_accuracy: 0.8333 - val_loss: 1.9924
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5333 - loss: 2.1869 - val_accuracy: 0.8333 - val_loss: 1.8585
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5333 - loss: 2.0948 - val_accuracy: 0.8333 - val_loss: 1.7016
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5333 - loss: 1.9874 - val_accuracy: 0.8333 - val_loss: 1.5231
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5333 - loss: 1.8663 - val_accuracy: 0.8333 - val_loss: 1.3309
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5333 - loss: 1.7379 - val_accuracy: 0.8333 - val_loss: 1.1434
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.5333 - loss: 1.6163 - val_accuracy: 0.8333 - val_loss: 0.9875
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.5333 - loss: 1.5228 - val_accuracy: 0.8333 - val_loss: 0.8872
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.5333 - loss: 1.4795 - val_accuracy: 0.8333 - val_loss: 0.8482
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5333 - loss: 1.4901 - val_accuracy: 0.8333 - val_loss: 0.8528
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.5333 - loss: 1.5247 - val_accuracy: 0.8333 - val_loss: 0.8731
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.5333 - loss: 1.5453 - val_accuracy: 0.8333 - val_loss: 0.8915
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5333 - loss: 1.5360 - val_accuracy: 0.8333 - val_loss: 0.9027
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.5333 - loss: 1.5009 - val_accuracy: 0.8333 - val_loss: 0.9079
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5333 - loss: 1.4516 - val_accuracy: 0.8333 - val_loss: 0.9106
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.5333 - loss: 1.4002 - val_accuracy: 0.8333 - val_loss: 0.9139
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.5333 - loss: 1.3556 - val_accuracy: 0.8333 - val_loss: 0.9204
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5333 - loss: 1.3225 - val_accuracy: 0.8333 - val_loss: 0.9306
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5333 - loss: 1.3013 - val_accuracy: 0.8333 - val_loss: 0.9439
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.5333 - loss: 1.2893 - val_accuracy: 0.8333 - val_loss: 0.9588
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5333 - loss: 1.2826 - val_accuracy: 0.8333 - val_loss: 0.9733
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5333 - loss: 1.2772 - val_accuracy: 0.8333 - val_loss: 0.9863
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5333 - loss: 1.2700 - val_accuracy: 0.8333 - val_loss: 0.9971
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.5333 - loss: 1.2594 - val_accuracy: 0.8333 - val_loss: 1.0061
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.5333 - loss: 1.2445 - val_accuracy: 0.8333 - val_loss: 1.0142
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.5333 - loss: 1.2258 - val_accuracy: 0.8333 - val_loss: 1.0228
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.5333 - loss: 1.2040 - val_accuracy: 0.8333 - val_loss: 1.0334
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.5333 - loss: 1.1804 - val_accuracy: 0.8333 - val_loss: 1.0471
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5333 - loss: 1.1565 - val_accuracy: 0.8333 - val_loss: 1.0649
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.5333 - loss: 1.1336 - val_accuracy: 0.8333 - val_loss: 1.0869
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5333 - loss: 1.1126 - val_accuracy: 0.8333 - val_loss: 1.1129
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5333 - loss: 1.0937 - val_accuracy: 0.8333 - val_loss: 1.1416
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5333 - loss: 1.0766 - val_accuracy: 0.8333 - val_loss: 1.1719
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5333 - loss: 1.0602 - val_accuracy: 0.8333 - val_loss: 1.2022
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5333 - loss: 1.0434 - val_accuracy: 0.8333 - val_loss: 1.2312
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5333 - loss: 1.0250 - val_accuracy: 0.8333 - val_loss: 1.2581
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5333 - loss: 1.0044 - val_accuracy: 0.8333 - val_loss: 1.2827
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5333 - loss: 0.9816 - val_accuracy: 0.8333 - val_loss: 1.3050
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5333 - loss: 0.9569 - val_accuracy: 0.8333 - val_loss: 1.3259
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5333 - loss: 0.9310 - val_accuracy: 0.8333 - val_loss: 1.3463
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5333 - loss: 0.9049 - val_accuracy: 0.8333 - val_loss: 1.3670
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6000 - loss: 0.8788 - val_accuracy: 0.8333 - val_loss: 1.3892
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6000 - loss: 0.8531 - val_accuracy: 0.8333 - val_loss: 1.4135
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6000 - loss: 0.8275 - val_accuracy: 0.8333 - val_loss: 1.4406
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6000 - loss: 0.8015 - val_accuracy: 0.8333 - val_loss: 1.4708
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6000 - loss: 0.7747 - val_accuracy: 0.8333 - val_loss: 1.5045
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6667 - loss: 0.7465 - val_accuracy: 0.8333 - val_loss: 1.5419
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8000 - loss: 0.7169 - val_accuracy: 0.8333 - val_loss: 1.5830
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8000 - loss: 0.6860 - val_accuracy: 0.8333 - val_loss: 1.6277
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8000 - loss: 0.6544 - val_accuracy: 0.8333 - val_loss: 1.6757
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8000 - loss: 0.6227 - val_accuracy: 0.8333 - val_loss: 1.7265
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9333 - loss: 0.5917 - val_accuracy: 0.8333 - val_loss: 1.7790
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9333 - loss: 0.5615 - val_accuracy: 0.8333 - val_loss: 1.8321
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9333 - loss: 0.5324 - val_accuracy: 0.8333 - val_loss: 1.8845
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9333 - loss: 0.5042 - val_accuracy: 0.8333 - val_loss: 1.9353
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9333 - loss: 0.4769 - val_accuracy: 0.8333 - val_loss: 1.9836
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9333 - loss: 0.4504 - val_accuracy: 0.8333 - val_loss: 2.0294
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9333 - loss: 0.4249 - val_accuracy: 0.8333 - val_loss: 2.0729
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9333 - loss: 0.4004 - val_accuracy: 0.8333 - val_loss: 2.1145
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 0.3769 - val_accuracy: 0.8333 - val_loss: 2.1547
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 1.0000 - loss: 0.3542 - val_accuracy: 0.8333 - val_loss: 2.1940
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.3321 - val_accuracy: 0.8333 - val_loss: 2.2322
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.3109 - val_accuracy: 0.8333 - val_loss: 2.2694
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.2907 - val_accuracy: 0.8333 - val_loss: 2.3052
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.2716 - val_accuracy: 0.8333 - val_loss: 2.3394
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.2532 - val_accuracy: 0.8333 - val_loss: 2.3716
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.2357 - val_accuracy: 0.8333 - val_loss: 2.4020
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.2190 - val_accuracy: 0.8333 - val_loss: 2.4304
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.2033 - val_accuracy: 0.8333 - val_loss: 2.4568
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.1888 - val_accuracy: 0.8333 - val_loss: 2.4814
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.1752 - val_accuracy: 0.8333 - val_loss: 2.5041
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.1624 - val_accuracy: 0.8333 - val_loss: 2.5251
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.1505 - val_accuracy: 0.8333 - val_loss: 2.5446
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 1.0000 - loss: 0.1396 - val_accuracy: 0.8333 - val_loss: 2.5628
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.1297 - val_accuracy: 0.8333 - val_loss: 2.5800
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 0.1207 - val_accuracy: 0.8333 - val_loss: 2.5966
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.1125 - val_accuracy: 0.8333 - val_loss: 2.6126
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.1049 - val_accuracy: 0.8333 - val_loss: 2.6281
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0981 - val_accuracy: 0.8333 - val_loss: 2.6429
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0920 - val_accuracy: 0.8333 - val_loss: 2.6568
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0864 - val_accuracy: 0.8333 - val_loss: 2.6695
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0813 - val_accuracy: 0.8333 - val_loss: 2.6808
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0766 - val_accuracy: 0.8333 - val_loss: 2.6909
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0723 - val_accuracy: 0.8333 - val_loss: 2.6999
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0683 - val_accuracy: 0.8333 - val_loss: 2.7081
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0646 - val_accuracy: 0.8333 - val_loss: 2.7158
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0612 - val_accuracy: 0.8333 - val_loss: 2.7233
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0580 - val_accuracy: 0.8333 - val_loss: 2.7307

# %%
# Encoder model for inference
encoder_model = Model(encoder_inputs, [state_h, state_c])

# Decoder model for inference
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_inputs_single = Input(shape=(1,))

# Create a new embedding layer for the decoder during inference
decoder_embedding_inference = Embedding(input_dim=len(fre_tokenizer.word_index) + 1, output_dim=embedding_dim)
decoder_inputs_single_x = decoder_embedding_inference(decoder_inputs_single)

# LSTM and Dense layers can be reused from the original model
decoder_outputs_single, state_h_dec, state_c_dec = decoder_lstm(decoder_inputs_single_x, initial_state=[decoder_state_input_h, decoder_state_input_c])
decoder_outputs_single = decoder_dense(decoder_outputs_single)

# Create the inference decoder model
decoder_model = Model([decoder_inputs_single, decoder_state_input_h, decoder_state_input_c],
                      [decoder_outputs_single, state_h_dec, state_c_dec])

# %%
def translate_sentence(input_seq):
    # Encode the input as state vectors
    states_value = encoder_model.predict(input_seq)

    # Generate an empty target sequence of length 1
    target_seq = np.zeros((1, 1))

    # Start the target sequence with the start word (usually index 1 or a special <START> token)
    target_seq[0, 0] = fre_tokenizer.word_index['bonjour']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample the next word
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_word = None
        for word, index in fre_tokenizer.word_index.items():
            if index == sampled_token_index:
                sampled_word = word
                break

        if sampled_word is None or sampled_word == '<end>':
            stop_condition = True
        else:
            decoded_sentence += ' ' + sampled_word

        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        # Update states
        states_value = [h, c]

    return decoded_sentence.strip()

# Test the model with a new sentence
test_sentence = "how are you"
test_seq = eng_tokenizer.texts_to_sequences([test_sentence])
test_seq_padded = pad_sequences(test_seq, maxlen=max_eng_len, padding='post')
translation = translate_sentence(test_seq_padded)
print("Translation:", translation)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Translation: ça
